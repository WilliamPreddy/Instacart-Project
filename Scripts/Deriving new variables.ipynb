# %% [markdown]
# # Importing

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import pickle
df_merged= pd.read_pickle(r'C:\Users\william\5-2023 Instacart Basket Analysis\Data\Prepared Data\orders_products_merged.pkl')

# %%
path=r'C:\Users\william\5-2023 Instacart Basket Analysis'

# %% [markdown]
# # Create Subset

# %%
df= df_merged[:1000000]

# %% [markdown]
# # If Statements

# %%
# If Statements
def price_label(row):
  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\William\AppData\Local\Temp\ipykernel_10132\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
# Price Check
df['prices'].max()
# Out:
# 14.8

# %%
# Using loc function
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Checking Values
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # loc Functions on Entire Dataframe

# %%
# Using loc function
df_merged.loc[df_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_merged.loc[(df_merged['prices'] <= 15) & (df_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_merged.loc[df_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21890146
# Low-range product     10126384
# High-range product      417682
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # Loop Functions

# %%
df_merged['order_dow'].value_counts(dropna = False)
# Out:
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: order_dow, dtype: int64

# %%
result = []

for value in df_merged["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_merged['busiest_day']= result

# %%
df_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: busiest_day, dtype: int64

# %% [markdown]
# # Task 4.7

# %%
#2 
# Two busiest days and two slowest days
result_2 = []

for value in df_merged["order_dow"]:
  if value == 0 or value == 1:
    result_2.append("Busiest days")
  elif value == 4 or value == 3:
    result_2.append("Least busy days")
  else:
    result_2.append("Regularly busy")

# %%
# Combine to data frame
df_merged['Busiest_days']= result_2

# %%
# Confirmation
df_merged.head(5)
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  order_dow  time_ordered  \
# 0             0   2539329        1             1          2             8
# 1             1   2398795        1             2          3             7
# 2             2    473747        1             3          3            12
# 3             3   2254736        1             4          4             7
# 4             4    431534        1             5          4            15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0_y product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
#3
# Checking the values of the new column
df_merged['Busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy     12927461
# Busiest days       11875462
# Least busy days     7631289
# Name: Busiest_days, dtype: int64

# %% [markdown]
# #### Upon adding up the frequency counts, it confirms that the loop operated the way it should

# %%
#4
# Busiest hours and new column
df_merged['time_ordered'].value_counts()
# Out:
# 10    2764390
# 11    2738585
# 14    2691563
# 15    2664522
# 13    2663272
# 12    2620800
# 16    2537469
# 9     2456661
# 17    2089452
# 8     1719952
# 18    1637922
# 19    1259382
# 20     977017
# 7      891928
# 21     796362
# 22     634737
# 23     402612
# 6      290770
# 0      218942
# 1      115786
# 5       88057
# 2       69431
# 4       53283
# 3       51317
# Name: time_ordered, dtype: int64

# %%
time_of_day = []

for value in df_merged["time_ordered"]:
  if value in [10, 11, 14, 15, 13, 12, 16, 9]:
    time_of_day.append("Most orders")
  elif value in [23, 6, 0, 1, 5, 2, 4, 3]:
    time_of_day.append("Fewest orders")
  else:
    time_of_day.append("Average orders")

# %%
df_merged['busiest_period_of_day'] = time_of_day

# %%
df_merged[['time_ordered', 'busiest_period_of_day']].head(5)
# Out:
#    time_ordered busiest_period_of_day
# 0             8        Average orders
# 1             7        Average orders
# 2            12           Most orders
# 3             7        Average orders
# 4            15           Most orders

# %%
#5
# Print frequency
df_merged['busiest_period_of_day'].value_counts()
# Out:
# Most orders       21137262
# Average orders    10006752
# Fewest orders      1290198
# Name: busiest_period_of_day, dtype: int64

# %%
#6
# Export Pickle
ords_prods_merged.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_merged_updated.pkl'))
