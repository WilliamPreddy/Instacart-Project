# %% [markdown]
# # Import Library

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import Pickle

# %%
# Import pickle
ords_prods_merged= pd.read_pickle(r'C:\Users\william\5-2023 Instacart Basket Analysis\Data\Prepared Data\orders_products_merged_updated.pkl')

# %% [markdown]
# # Creating Subset

# %%
# Subset creation
df = ords_prods_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 20)

# %%
df.head(5)
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  order_dow  time_ordered  \
# 0             0   2539329        1             1          2             8
# 1             1   2398795        1             2          3             7
# 2             2    473747        1             3          3            12
# 3             3   2254736        1             4          4             7
# 4             4    431534        1             5          4            15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0_y product_name  aisle_id  department_id  prices _merge  \
# ...

# %% [markdown]
# # Grouping Data

# %%
# Using groupby() function
df.groupby('product_name')

# %% [markdown]
# # Aggregating Data

# %%
# Aggregation
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# # Aggregating Data with Transform() Function

# %%
# Creating a flag
ords_prods_merged['max_order'] = ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merged.head(15)
# Out:
#     Unnamed: 0_x  order_id  user_id  order_number  order_dow  time_ordered  \
# 0              0   2539329        1             1          2             8
# 1              1   2398795        1             2          3             7
# 2              2    473747        1             3          3            12
# 3              3   2254736        1             4          4             7
# 4              4    431534        1             5          4            15
# 5              5   3367565        1             6          2             7
# 6              6    550135        1             7          1             9
# 7              7   3108588        1             8          1            14
# 8              8   2295261        1             9          1            16
# 9              9   2550362        1            10          4             8
# 10           144   2968173       15            15          1             9
# ...

# %%
ords_prods_merged.head(100)
# Out:
#     Unnamed: 0_x  order_id  user_id  order_number  order_dow  time_ordered  \
# 0              0   2539329        1             1          2             8
# 1              1   2398795        1             2          3             7
# 2              2    473747        1             3          3            12
# 3              3   2254736        1             4          4             7
# 4              4    431534        1             5          4            15
# ..           ...       ...      ...           ...        ...           ...
# 95          5895   3226575      360             1          5            12
# 96          6137   1469869      377             3          5            17
# 97          6259   1927023      387             2          4            10
# 98          6740    858092      420             4          1            19
# 99          6741    119314      420             5          3            19
#
# ...

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merged.head(100)
# Out:
#     Unnamed: 0_x  order_id  user_id  order_number  order_dow  time_ordered  \
# 0              0   2539329        1             1          2             8
# 1              1   2398795        1             2          3             7
# 2              2    473747        1             3          3            12
# 3              3   2254736        1             4          4             7
# 4              4    431534        1             5          4            15
# 5              5   3367565        1             6          2             7
# 6              6    550135        1             7          1             9
# 7              7   3108588        1             8          1            14
# 8              8   2295261        1             9          1            16
# 9              9   2550362        1            10          4             8
# 10           144   2968173       15            15          1             9
# ...

# %% [markdown]
# # Deriving Columns with loc() Function

# %%
# Setting up flag system in new column
ords_prods_merged.loc[ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merged.loc[(ords_prods_merged['max_order'] <= 40) & (ords_prods_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merged.loc[ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merged['loyalty_flag'].value_counts(dropna=False)
# Out:
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merged[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %% [markdown]
# # Export Pickle

# %%
path=r'C:\Users\william\5-2023 Instacart Basket Analysis'

# %%
ords_prods_merged.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_merged_updated_again.pkl'))

# %%
# Import pickle
ords_prods_merge= pd.read_pickle(r'C:\Users\william\5-2023 Instacart Basket Analysis\Data\Prepared Data\orders_products_merged_updated_again_and_again.pkl')

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan

# %%
ords_prods_merge['prices'].max()
# Out:
# 25.0

# %%
ords_prods_merge.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_merged_updated_again_and_again.pkl'))
